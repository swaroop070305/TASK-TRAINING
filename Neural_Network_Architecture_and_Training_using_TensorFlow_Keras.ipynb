# %% [markdown]
# <a href="https://colab.research.google.com/github/swaroop070305/TASK-TRAINING/blob/main/Neural_Network_Architecture_and_Training_using_TensorFlow_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network Architecture and Training using TensorFlow/Keras

# %% [markdown]
# ## 1. Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.20.0

# %% [markdown]
# ## 2. Create Sample Data

# %%
# Sample input and output

X = np.array([[1],[2],[3],[4],[5]], dtype=float)
y = np.array([[2],[4],[6],[8],[10]], dtype=float)

print("Input:")
print(X)

print("Output:")
print(y)
# Out:
# Input:
# [[1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]]
# Output:
# [[ 2.]
#  [ 4.]
#  [ 6.]
#  [ 8.]
#  [10.]]

# %% [markdown]
# ## 3. Build the Neural Network

# %%
model = Sequential([
    Dense(8, activation='relu', input_shape=(1,)),
    Dense(1)
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25 (100.00 B)
#  Trainable params: 25 (100.00 B)
# ...

# %% [markdown]
# ## 4. Compile the Model

# %%
model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mae']
)

print("Model Compiled Successfully")
# Out:
# Model Compiled Successfully

# %% [markdown]
# ## 5. Train the Model

# %%
history = model.fit(
    X,
    y,
    epochs=100,
    verbose=0
)

print("Training Completed")
# Out:
# Training Completed

# %% [markdown]
# ## 6. Test the Model

# %%
prediction = model.predict([[6]])

print("Prediction for input 6:")
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1346/1763412837.py in <cell line: 0>()
# ----> 1 prediction = model.predict([[6]])
#       2
#       3 print("Prediction for input 6:")
#       4 print(prediction)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/__init__.py in get_data_adapter(x, y, sample_weight, batch_size, steps_per_epoch, shuffle, class_weight)
#     161         # )
#     162     else:
# ...

# %% [markdown]
# ## 7. Evaluate the Model

# %%
loss, mae = model.evaluate(X, y, verbose=0)

print("Loss:", loss)
print("MAE:", mae)
# Out:
# Loss: 35.73811340332031
# MAE: 5.376747131347656
