# %% [markdown]
# <a href="https://colab.research.google.com/github/swaroop070305/TASK-TRAINING/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn Basics

# %% [markdown]
# ## Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# ## Load Sample Dataset

# %%
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.show()

# %% [markdown]
# ## Line Plot

# %%
sns.lineplot(data=tips, x="size", y="tip")
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot(data=tips, x="day", y="total_bill")
plt.show()

# %% [markdown]
# ## Histogram

# %%
sns.histplot(data=tips, x="total_bill")
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(data=tips, x="day", y="total_bill")
plt.show()

# %% [markdown]
# ## Count Plot

# %%
sns.countplot(data=tips, x="day")
plt.show()

# %% [markdown]
# ## Heatmap

# %%
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()
